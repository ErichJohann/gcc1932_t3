# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%);
#     padding: 30px;
#     border-radius: 10px;
#     box-shadow: 0 4px 15px rgba(0,0,0,0.1);
#     text-align: center;
#     font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#     margin-bottom: 20px;
# ">
#     <h1 style="color: #ffffff; margin: 0 0 15px 0; font-size: 32px; font-weight: 700; letter-spacing: 1px;">
#         Early Stopping com Validação Dinâmica em Blocos
#     </h1>
#     <hr style="border: 0; height: 1px; background: rgba(255,255,255,0.3); margin: 0 auto 15px auto; width: 40%;">
# </div>

# %% [markdown]
# # Contexto

# %% [markdown]
# No treinamento de redes neurais frequentemente os dados são separados em treino, teste e validação. Com esse último sendo usado para averiguar a generalização do modelo durante o treinamento. Em uma abordagem comum, usa-se early stopping para parar antes do final das épocas de treinamento visando atingir o ponto de mínimo de loss no conjunto de validação, o modelo mais generalista. Se o modelo parar muito cedo ele pode sofre de underfitting e se não parar e ir até o final pode sofrer de overfitting.
# ![image.png](attachment:image.png) - Mrinal W.. (Oct 31, 2022). Overfitting in Machine Learning and Computer Vision. Roboflow Blog: https://blog.roboflow.com/overfitting-machine-learning-computer-vision/
# A figura mostra o ponto de parada ideal do early stopping.
#
# Uma outra abordagem é o early stopping dinâmico. Diferente do tradicional que mantém os conjuntos de treino e validação fixos, os exemplos são reamostrados a cada época. Essa técnica tem o objetivo de não tornar o early stopping dependente de somente uma partição específica dos dados, além de promover a utilização total dos dados disponíveis.
#
# Entretanto com a reamostragem dos dados a cada época a curva de loss acaba se tornando bastante ruidosa, variando bem mais que um modelo tradicional. Dessa forma esse experimento visa analisar uma abordagem intermediária para mitigar esse problema, na qual os dados dos dois conjuntos seriam congelados por X épocas, realizando early stopping com validação dinâmica por blocos.

# %% [markdown]
# # Experimento
#
# * Serão analizados dois conjuntos de dados voltados para problemas de regressão e classificação:
#     * [Student](https://doi.org/10.24432/C5TG7T)
#     * [Titanic](https://github.com/datasciencedojo/datasets/blob/master/titanic.csv)
# * Modelos testados: redes mlp
#     * Parâmetros gerais:
#         * Hidden sizes - (64,32)
#         * Dropout - 0.1
#         * Val ration - 0.2
#         * Batch size - 64
#         * Learning rate - 0.001
#         * Min delta: float - 1e-4
#         * Epochs - 10000
#     * Estratégias de early stopping:
#         * Paciência (paciencia - 100)
#         * Teste t (test_window - 60 | p_value - 0.1)
#     * Número de Blocos - [1, 5, 10, 20, 30, 50]
#     * Também será treinado um modelo base early stopping estático para comparação
#     * Cada modelo foi testado com 30 seeds aleatórias

# %% [markdown]
# # Carregando datasets que serão usados

# %% [markdown]
# ### Student

# %%
import os
import urllib.request
import zipfile
import pandas as pd

arquivo = "student-mat.csv"
url_zip = "https://archive.ics.uci.edu/ml/machine-learning-databases/00320/student.zip"

if not os.path.exists(arquivo):
    temp_zip = "temp_student.zip"

    # Baixa o arquivo zip
    urllib.request.urlretrieve(url_zip, temp_zip)

    # Extrai apenas o arquivo necessário
    with zipfile.ZipFile(temp_zip, 'r') as zip_ref:
        zip_ref.extract(arquivo, path=".")

    os.remove(temp_zip)
    print("Baixado student-mat.csv via student.zip da UCI.")

else:
    print("student-mat.csv já existe localmente.")

student = pd.read_csv(arquivo, sep=";")
# Out:
# student-mat.csv já existe localmente.

# %% [markdown]
# ### Titanic

# %%
url_titanic = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

dataset = pd.read_csv(url_titanic)

# Renomear coluna alvo para seguir o mesmo padrão do wine (Survived -> Class)
dataset = dataset.rename(columns={"Survived": "Class"})

# Converter para o tipo "category" (equivalente ao factor do R)
dataset["Class"] = dataset["Class"].astype("category")

print("Dataset Titanic carregado do link e salvo como 'dataset' com target = 'Class'.")
# Out:
# Dataset Titanic carregado do link e salvo como 'dataset' com target = 'Class'.

# %% [markdown]
# # Pré Processamento de dados

# %% [markdown]
# ### Student
# - One hot encoding de variáveis categóricas
# - Separação treino/teste 80/20
# - Normalização Min-max

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

dataset_student = student.copy()
seed_utilizada = 42

target_student = "G3"

X_student = dataset_student.drop(columns=[target_student])
y_student = dataset_student[target_student]

#One-hot encoding em todas as variáveis categóricas
X_student_encoded = pd.get_dummies(X_student, drop_first=False, dtype=int)

X_train, X_test, y_train, y_test = train_test_split(
    X_student_encoded, y_student, test_size=0.2, random_state=seed_utilizada
)

# Scaling baseado APENAS no treino (MinMax)
scaler_student = MinMaxScaler()

train_scaled_student = scaler_student.fit_transform(X_train)
test_scaled_student = scaler_student.transform(X_test)

student_cols = X_train.columns.tolist()
df_train_mlp_reg = pd.DataFrame(train_scaled_student, columns=student_cols)
df_test_mlp_reg = pd.DataFrame(test_scaled_student, columns=student_cols)

df_train_mlp_reg[target_student] = y_train.values
df_test_mlp_reg[target_student] = y_test.values

input_dim_student = len(student_cols)

print("Pré-processamento do Student Performance concluído.")
print(f"Formato do Treino: {train_scaled_student.shape} | Teste: {test_scaled_student.shape}")
# Out:
# Pré-processamento do Student Performance concluído.
# Formato do Treino: (316, 58) | Teste: (79, 58)

# %% [markdown]
# ### Titanic
# - Seleção de colunas numéricas válidas
# - Omissão de valores faltantes
# - Separação treino/teste 80/20
# - Normalização Min-max

# %%
target_titanic = "Class"
seed_utilizada = 42
numeric_features = ["Pclass", "Age", "SibSp", "Parch", "Fare"]

# Cria uma cópia focando apenas nas colunas desejadas
dataset_titanic = dataset[numeric_features + [target_titanic]].copy()

# Remove linhas com valores ausentes (NaN) nas colunas selecionadas
dataset_titanic = dataset_titanic.dropna()

X_titanic = dataset_titanic[numeric_features]
y_titanic = dataset_titanic[target_titanic]
slevels_titanic = list(y_titanic.unique())


X_train_t, X_test_t, y_train_t, y_test_t = train_test_split(
    X_titanic, y_titanic, test_size=0.2, random_state=seed_utilizada
)

# Scaling usando apenas treino
scaler_titanic = MinMaxScaler()

train_scaled_titanic = scaler_titanic.fit_transform(X_train_t)
test_scaled_titanic = scaler_titanic.transform(X_test_t)

df_train_mlp_cla = pd.DataFrame(train_scaled_titanic, columns=numeric_features)

# Inserir coluna alvo 'Class' usando .values para alinhar os índices
df_train_mlp_cla["Class"] = y_train_t.values 

df_test_mlp_cla = pd.DataFrame(test_scaled_titanic, columns=numeric_features)

input_dim_titanic = len(numeric_features)
num_class = df_train_mlp_cla["Class"].nunique() # Retorna 2 (Sobreviveu ou Não)

print("Pré-processamento Titanic concluído.")
print(f"Formato do Treino: {train_scaled_titanic.shape} | Validação: {test_scaled_titanic.shape}")
# Out:
# Pré-processamento Titanic concluído.
# Formato do Treino: (571, 5) | Validação: (143, 5)

# %% [markdown]
# # Configurações de treinamento

# %% [markdown]
# - Set up configurações de treinamento

# %%
import random
import numpy as np
import torch

#Função para definição de seeds
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

#Arq da rede mlp
hidden_sizes = [64, 32]

#Blocos de validação que serão usados
Blocos = [1, 5, 10, 20, 30, 50]
experiments_results_cla = []
experiments_results_reg = []
loss_hist_cla={}
loss_hist_reg={}

seed = 42
seeds = []
seed_everything(seed)
#Geração de 30 seeds aletaórias
if not seeds:
    for i in range(30):
        s = random.randint(10000000, 99999999)
        seeds.append(s)

print("Configurações de treinamento setadas")
print(f"Seeds geradas: {seeds}")
# Out:
# Configurações de treinamento setadas
# Seeds geradas: [95822412, 24942603, 13356886, 46913810, 42868828, 39958838, 28728463, 23756669, 83197857, 21668732, 89254563, 66629388, 14265799, 13999315, 22575562, 39345092, 41227216, 77827638, 90801586, 13561597, 85329037, 36687537, 97226012, 83140807, 66306997, 39587039, 70291817, 89089901, 47338124, 10872248]

# %% [markdown]
# # Classificação

# %% [markdown]
# ### MLP Classificação

# %%
"""
Unified PyTorch MLP classifier used by daltoolboxdp via reticulate. (modified)
"""

from dataclasses import dataclass
from typing import List, Optional, Tuple

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from scipy.stats import ttest_ind
from torch.utils.data import DataLoader, TensorDataset


VALIDATION_STRATEGIES = {"static", "dynamic"}
STOPPING_RULES = {"none", "patience", "sma", "ema", "h"}


@dataclass
class _TrainingConfig:
    epochs: int = 100
    lr: float = 0.001
    val_ratio: float = 0.2
    batch_size: int = 64
    patience: int = 100
    min_delta: float = 1e-4
    sma_window: int = 5
    ema_alpha: float = 0.2
    test_window: int = 30
    p_value: float = 0.05
    weight_decay: float = 0.0
    B: int = 1


def _activation_module(name: str) -> nn.Module:
    name = str(name).lower()
    if name == "relu":
        return nn.ReLU(inplace=True)
    if name == "leaky_relu":
        return nn.LeakyReLU(0.2, inplace=True)
    if name == "elu":
        return nn.ELU(inplace=True)
    if name == "gelu":
        return nn.GELU()
    if name == "tanh":
        return nn.Tanh()
    raise ValueError(f"Unsupported activation: {name}")


def _normalization_module(kind: str, dim: int) -> Optional[nn.Module]:
    kind = str(kind).lower()
    if kind == "none":
        return None
    if kind == "batch":
        return nn.BatchNorm1d(int(dim))
    if kind == "layer":
        return nn.LayerNorm(int(dim))
    raise ValueError("normalization must be one of {'none', 'batch', 'layer'}")


def _apply_init(module: nn.Module, init_method: str):
    init_method = str(init_method).lower()
    if isinstance(module, nn.Linear):
        if init_method == "xavier_uniform":
            nn.init.xavier_uniform_(module.weight)
        elif init_method == "xavier_normal":
            nn.init.xavier_normal_(module.weight)
        elif init_method == "kaiming_uniform":
            nn.init.kaiming_uniform_(module.weight, nonlinearity="relu")
        elif init_method == "kaiming_normal":
            nn.init.kaiming_normal_(module.weight, nonlinearity="relu")
        elif init_method == "default":
            return
        else:
            raise ValueError(f"Unsupported init_method: {init_method}")
        if module.bias is not None:
            nn.init.zeros_(module.bias)


class TorchMLPClassifierNet(nn.Module):
    def __init__(
        self,
        input_dim: int,
        hidden_sizes: List[int],
        num_classes: int,
        dropout: float = 0.0,
        activation: str = "relu",
        normalization: str = "none",
        init_method: str = "default",
    ):
        super().__init__()
        layers = []
        prev = int(input_dim)
        if isinstance(hidden_sizes, (int, np.integer)):
            hidden_sizes = [int(hidden_sizes)]
        for h in hidden_sizes:
            layers.append(nn.Linear(prev, int(h)))
            norm = _normalization_module(normalization, int(h))
            if norm is not None:
                layers.append(norm)
            layers.append(_activation_module(activation))
            if float(dropout) > 0:
                layers.append(nn.Dropout(p=float(dropout)))
            prev = int(h)
        layers.append(nn.Linear(prev, int(num_classes)))
        self.net = nn.Sequential(*layers)
        self.net.apply(lambda module: _apply_init(module, init_method))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.net(x)


class _StopController:
    def __init__(self, rule: str, min_delta: float, patience: int, sma_window: int, ema_alpha: float, test_window: int, p_value: float):
        self.rule = rule
        self.min_delta = float(min_delta)
        self.patience = int(patience)
        self.sma_window = max(1, int(sma_window))
        self.ema_alpha = float(ema_alpha)
        self.test_window = max(2, int(test_window))
        self.p_value = float(p_value)
        self.best_value = float("inf")
        self.best_state = None
        self.patience_ctr = 0
        self.ema_value = None
        self.val_history: List[float] = []

    def _clone_state(self, model: nn.Module):
        return {k: v.detach().clone() for k, v in model.state_dict().items()}

    def _h_improved(self) -> bool:
        if len(self.val_history) < 2 * self.test_window:
            if len(self.val_history) == 1:
                return True
            return self.val_history[-1] < min(self.val_history[:-1])
        prev_window = self.val_history[-2 * self.test_window : -self.test_window]
        recent_window = self.val_history[-self.test_window :]
        _, p_value = ttest_ind(prev_window, recent_window, equal_var=False, alternative="greater")
        return bool(p_value < self.p_value)

    def step(self, model: nn.Module, current: float) -> bool:
        self.val_history.append(float(current))
        if self.rule == "none":
            self.best_state = self._clone_state(model)
            return False
        if self.rule == "h":
            improved = self._h_improved()
            if improved:
                self.best_state = self._clone_state(model)
                self.patience_ctr = 0
            else:
                self.patience_ctr += 1
            return self.patience_ctr >= self.patience

        if self.rule == "patience":
            monitor_value = float(current)
        elif self.rule == "sma":
            monitor_value = float(np.mean(self.val_history[-self.sma_window :]))
        elif self.rule == "ema":
            if self.ema_value is None:
                self.ema_value = current
            else:
                self.ema_value = self.ema_alpha * current + (1.0 - self.ema_alpha) * self.ema_value
            monitor_value = float(self.ema_value)
        else:
            raise ValueError(f"Unsupported stopping rule: {self.rule}")

        if (self.best_value - monitor_value) > self.min_delta:
            self.best_value = monitor_value
            self.best_state = self._clone_state(model)
            self.patience_ctr = 0
        else:
            self.patience_ctr += 1
        return self.patience_ctr >= self.patience


class TorchMLPClassifier:
    def __init__(
        self,
        input_dim: int,
        hidden_sizes: List[int],
        num_classes: int,
        dropout: float = 0.0,
        activation: str = "relu",
        normalization: str = "none",
        init_method: str = "default",
        validation_strategy: str = "static",
        stopping_rule: str = "none",
    ):
        validation_strategy = str(validation_strategy).lower()
        stopping_rule = str(stopping_rule).lower()
        if validation_strategy not in VALIDATION_STRATEGIES:
            raise ValueError(f"validation_strategy must be one of {sorted(VALIDATION_STRATEGIES)}")
        if stopping_rule not in STOPPING_RULES:
            raise ValueError(f"stopping_rule must be one of {sorted(STOPPING_RULES)}")
        self.validation_strategy = validation_strategy
        self.stopping_rule = stopping_rule
        self.network = TorchMLPClassifierNet(
            input_dim,
            hidden_sizes,
            num_classes,
            dropout=dropout,
            activation=activation,
            normalization=normalization,
            init_method=init_method,
        ).to(self._device())
        self.classes_: List = []
        self.train_loss_hist: List[float] = []
        self.val_loss_hist: List[float] = []
        self.epochs_done: int = 0

    @staticmethod
    def _device():
        return torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    @staticmethod
    def _prepare_xy(df: pd.DataFrame, target_column: str, classes_: Optional[List]) -> Tuple[torch.Tensor, torch.Tensor, List]:
        X = df.drop(columns=[target_column]).to_numpy().astype(np.float32)
        y_raw = df[target_column].to_numpy()
        if classes_ is None:
            classes_ = sorted(pd.Series(y_raw).astype("category").cat.categories.tolist())
        class_to_idx = {c: i for i, c in enumerate(classes_)}
        y = np.array([class_to_idx[c] for c in y_raw], dtype=np.int64)
        return torch.from_numpy(X), torch.from_numpy(y), classes_

    @staticmethod
    def _split_indices(n_samples: int, val_ratio: float) -> Tuple[np.ndarray, np.ndarray]:
        idx = np.arange(n_samples)
        np.random.shuffle(idx)
        n_val = max(1, int(n_samples * float(val_ratio)))
        return  idx[n_val:], idx[:n_val]

    def _epoch(self, loader: DataLoader, optimizer: Optional[torch.optim.Optimizer], criterion: nn.Module) -> float:
        losses: List[float] = []
        if optimizer is None:
            self.network.eval()
            with torch.no_grad():
                for xb, yb in loader:
                    xb = xb.float().to(self._device())
                    yb = yb.long().to(self._device())
                    losses.append(float(criterion(self.network(xb), yb).item()))
        else:
            self.network.train()
            for xb, yb in loader:
                xb = xb.float().to(self._device())
                yb = yb.long().to(self._device())
                optimizer.zero_grad()
                loss = criterion(self.network(xb), yb)
                loss.backward()
                optimizer.step()
                losses.append(float(loss.item()))
        return float(np.mean(losses)) if losses else 0.0

    def fit(self, df_train: pd.DataFrame, target_column: str, config: _TrainingConfig, classes_: Optional[List] = None):

        X_all, y_all, self.classes_ = self._prepare_xy(df_train, target_column, classes_)
        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(self.network.parameters(), lr=float(config.lr), weight_decay=float(config.weight_decay))
        stopper = _StopController(self.stopping_rule, config.min_delta, config.patience, config.sma_window, config.ema_alpha, config.test_window, config.p_value)

        self.train_loss_hist = []
        self.val_loss_hist = []
        self.epochs_done = 0

        if self.validation_strategy == "static" and self.stopping_rule != "none":
            train_idx, val_idx = self._split_indices(X_all.shape[0], config.val_ratio)
            train_loader = DataLoader(TensorDataset(X_all[train_idx], y_all[train_idx]), batch_size=int(config.batch_size), shuffle=True, drop_last=False)
            val_loader = DataLoader(TensorDataset(X_all[val_idx], y_all[val_idx]), batch_size=int(config.batch_size), shuffle=False, drop_last=False)
        elif self.validation_strategy == "static":
            train_loader = DataLoader(TensorDataset(X_all, y_all), batch_size=int(config.batch_size), shuffle=True, drop_last=False)
            val_loader = None
        else:
            train_loader = None
            val_loader = None

        for epoch in range(int(config.epochs)):
            self.epochs_done += 1
            if self.validation_strategy == "dynamic" and (epoch % config.B) == 0:
                train_idx, val_idx = self._split_indices(X_all.shape[0], config.val_ratio)
                train_loader = DataLoader(TensorDataset(X_all[train_idx], y_all[train_idx]), batch_size=int(config.batch_size), shuffle=True, drop_last=False)
                val_loader = DataLoader(TensorDataset(X_all[val_idx], y_all[val_idx]), batch_size=int(config.batch_size), shuffle=False, drop_last=False)

            self.train_loss_hist.append(self._epoch(train_loader, optimizer, criterion))
            if val_loader is not None:
                val_loss = self._epoch(val_loader, None, criterion)
                self.val_loss_hist.append(val_loss)
                if stopper.step(self.network, val_loss):
                    break

        if stopper.best_state is not None:
            self.network.load_state_dict(stopper.best_state)
        return self

    def predict(self, df_test: pd.DataFrame):
        X = torch.from_numpy(df_test.to_numpy().astype(np.float32))
        self.network.eval()
        with torch.no_grad():
            logits = self.network(X.to(self._device()))
            pred_idx = torch.argmax(logits, dim=-1).cpu().numpy().tolist()
        idx_to_class = {i: c for i, c in enumerate(self.classes_)}
        return [idx_to_class[i] for i in pred_idx]

    def predict_scores(self, df_test: pd.DataFrame):
        X = torch.from_numpy(df_test.to_numpy().astype(np.float32))
        self.network.eval()
        with torch.no_grad():
            logits = self.network(X.to(self._device()))
            scores = F.softmax(logits, dim=-1).cpu().numpy()
        return scores.tolist()


def torch_cla_mlp_create(
    input_dim: int,
    hidden_sizes: List[int],
    num_classes: int,
    dropout: float = 0.0,
    activation: str = "relu",
    normalization: str = "none",
    init_method: str = "default",
    validation_strategy: str = "static",
    stopping_rule: str = "none",
):
    return TorchMLPClassifier(
        input_dim,
        hidden_sizes,
        num_classes,
        dropout=dropout,
        activation=activation,
        normalization=normalization,
        init_method=init_method,
        validation_strategy=validation_strategy,
        stopping_rule=stopping_rule,
    )


def torch_cla_mlp_fit(
    model,
    df_train: pd.DataFrame,
    target_column: str,
    epochs: int = 100,
    lr: float = 1e-3,
    validation_strategy: str = "static",
    stopping_rule: str = "none",
    batch_size: int = 64,
    val_ratio: float = 0.2,
    patience: int = 100,
    min_delta: float = 1e-4,
    sma_window: int = 5,
    ema_alpha: float = 0.2,
    test_window: int = 30,
    p_value: float = 0.05,
    weight_decay: float = 0.0,
    classes_: Optional[List] = None,
    B: int = 1
):
    model.validation_strategy = str(validation_strategy).lower()
    model.stopping_rule = str(stopping_rule).lower()
    config = _TrainingConfig(
        epochs=int(epochs),
        lr=float(lr),
        val_ratio=float(val_ratio),
        batch_size=int(batch_size),
        patience=int(patience),
        min_delta=float(min_delta),
        sma_window=int(sma_window),
        ema_alpha=float(ema_alpha),
        test_window=int(test_window),
        p_value=float(p_value),
        weight_decay=float(weight_decay),
        B=int(B)
    )
    return model.fit(df_train, target_column=target_column, config=config, classes_=classes_)


def torch_cla_mlp_predict(model, df_test: pd.DataFrame, classes_: Optional[List] = None):
    if classes_ is not None and not model.classes_:
        model.classes_ = list(classes_)
    return model.predict(df_test)


def torch_cla_mlp_predict_scores(model, df_test: pd.DataFrame, classes_: Optional[List] = None):
    if classes_ is not None and not model.classes_:
        model.classes_ = list(classes_)
    return model.predict_scores(df_test)

# %% [markdown]
# ### Treinamento modelo estático

# %%
from sklearn.metrics import classification_report

es_rules = ['patience', 'h']

for sr in es_rules:
    for s in seeds:
        seed_everything(s)
        
        mlp_cla_es = TorchMLPClassifier(
            input_dim=input_dim_titanic,
            hidden_sizes=hidden_sizes,
            num_classes=num_class,
            dropout=0.1,
            validation_strategy='static',
            stopping_rule=sr
        )
        
        mlp_cla_es = torch_cla_mlp_fit(
            model=mlp_cla_es,
            df_train=df_train_mlp_cla,
            target_column=target_titanic,
            epochs=10000,
            validation_strategy='static',
            stopping_rule=sr,
            test_window=60,
            p_value=0.1
        )
        
        loss_hist_cla[f"{sr} static b{None} s{s}"] = {
            "train_loss": mlp_cla_es.train_loss_hist,
            "val_loss": mlp_cla_es.val_loss_hist,
            "model": f"{sr} static"
        }

        preds = torch_cla_mlp_predict(mlp_cla_es, df_test_mlp_cla)
        
        report = classification_report(y_test_t, preds, output_dict=True)
        experiments_results_cla.append({
            "model": f"{sr} static",
            "acc": report["accuracy"],
            "precision": report["macro avg"]["precision"],
            "recall": report["macro avg"]["recall"],
            "F1": report["macro avg"]["f1-score"],
            "epochs": mlp_cla_es.epochs_done,
            "seed": s
        })

# %% [markdown]
# ### Treinamento validação em blocos

# %%
from sklearn.metrics import classification_report

es_rules = ['patience', 'h']

for sr in es_rules:
    for b in Blocos:
        for s in seeds:
            seed_everything(s)
            
            mlp_cla_es = TorchMLPClassifier(
                input_dim=input_dim_titanic,
                hidden_sizes=hidden_sizes,
                num_classes=num_class,
                dropout=0.1,
                validation_strategy='dynamic',
                stopping_rule=sr
            )
            
            mlp_cla_es = torch_cla_mlp_fit(
                model=mlp_cla_es,
                df_train=df_train_mlp_cla,
                target_column=target_titanic,
                epochs=10000,
                validation_strategy='dynamic',
                stopping_rule=sr,
                B=b,
                test_window=60,
                p_value=0.1
            )
            
            loss_hist_cla[f"{sr} dynamic b{b:02d} s{s}"] = {
                "train_loss": mlp_cla_es.train_loss_hist,
                "val_loss": mlp_cla_es.val_loss_hist,
                "model": f"{sr} dynamic {b:02d}"
            }

            preds = torch_cla_mlp_predict(mlp_cla_es, df_test_mlp_cla)
            
            report = classification_report(y_test_t, preds, output_dict=True)
            experiments_results_cla.append({
                "model": f"{sr} dynamic {b:02d}",
                "acc": report["accuracy"],
                "precision": report["macro avg"]["precision"],
                "recall": report["macro avg"]["recall"],
                "F1": report["macro avg"]["f1-score"],
                "epochs": mlp_cla_es.epochs_done,
                "seed": s
            })

# %% [markdown]
# ### Salvando resultados

# %%
import json

df_res_cla = pd.DataFrame(experiments_results_cla)
df_res_cla.to_csv("results_cla.csv", index=False)

with open("loss_hist_cla.json", "w") as f:
    json.dump(loss_hist_cla, f, indent=4)

# %% [markdown]
# # Regressão

# %% [markdown]
# ### Modelo MLP Regressão

# %%
"""
Unified PyTorch MLP regressor used by daltoolboxdp via reticulate. (modified)
"""

from dataclasses import dataclass
from typing import List, Optional, Tuple

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from scipy.stats import ttest_ind
from torch.utils.data import DataLoader, TensorDataset


VALIDATION_STRATEGIES = {"static", "dynamic"}
STOPPING_RULES = {"none", "patience", "sma", "ema", "h"}


@dataclass
class _TrainingConfig:
    epochs: int = 100
    lr: float = 0.001
    val_ratio: float = 0.2
    batch_size: int = 64
    patience: int = 100
    min_delta: float = 1e-4
    sma_window: int = 5
    ema_alpha: float = 0.2
    test_window: int = 30
    p_value: float = 0.05
    B: int = 1


def _activation_module(name: str) -> nn.Module:
    name = str(name).lower()
    if name == "relu":
        return nn.ReLU(inplace=True)
    if name == "leaky_relu":
        return nn.LeakyReLU(0.2, inplace=True)
    if name == "elu":
        return nn.ELU(inplace=True)
    if name == "gelu":
        return nn.GELU()
    if name == "tanh":
        return nn.Tanh()
    raise ValueError(f"Unsupported activation: {name}")


def _output_activation_module(name: str) -> Optional[nn.Module]:
    name = str(name).lower()
    if name in {"none", "identity"}:
        return None
    if name == "relu":
        return nn.ReLU(inplace=True)
    if name == "sigmoid":
        return nn.Sigmoid()
    if name == "tanh":
        return nn.Tanh()
    if name == "softplus":
        return nn.Softplus()
    raise ValueError(f"Unsupported output_activation: {name}")


def _normalization_module(kind: str, dim: int) -> Optional[nn.Module]:
    kind = str(kind).lower()
    if kind == "none":
        return None
    if kind == "batch":
        return nn.BatchNorm1d(int(dim))
    if kind == "layer":
        return nn.LayerNorm(int(dim))
    raise ValueError("normalization must be one of {'none', 'batch', 'layer'}")


def _apply_init(module: nn.Module, init_method: str):
    init_method = str(init_method).lower()
    if isinstance(module, nn.Linear):
        if init_method == "xavier_uniform":
            nn.init.xavier_uniform_(module.weight)
        elif init_method == "xavier_normal":
            nn.init.xavier_normal_(module.weight)
        elif init_method == "kaiming_uniform":
            nn.init.kaiming_uniform_(module.weight, nonlinearity="relu")
        elif init_method == "kaiming_normal":
            nn.init.kaiming_normal_(module.weight, nonlinearity="relu")
        elif init_method == "default":
            return
        else:
            raise ValueError(f"Unsupported init_method: {init_method}")
        if module.bias is not None:
            nn.init.zeros_(module.bias)


class TorchMLPRegressorNet(nn.Module):
    def __init__(
        self,
        input_dim: int,
        hidden_sizes: List[int],
        dropout: float = 0.0,
        activation: str = "relu",
        output_activation: str = "none",
        normalization: str = "none",
        init_method: str = "default",
    ):
        super().__init__()
        layers = []
        prev = int(input_dim)
        if isinstance(hidden_sizes, (int, np.integer)):
            hidden_sizes = [int(hidden_sizes)]
        for h in hidden_sizes:
            layers.append(nn.Linear(prev, int(h)))
            norm = _normalization_module(normalization, int(h))
            if norm is not None:
                layers.append(norm)
            layers.append(_activation_module(activation))
            if float(dropout) > 0:
                layers.append(nn.Dropout(p=float(dropout)))
            prev = int(h)
        layers.append(nn.Linear(prev, 1))
        out_act = _output_activation_module(output_activation)
        if out_act is not None:
            layers.append(out_act)
        self.net = nn.Sequential(*layers)
        self.net.apply(lambda module: _apply_init(module, init_method))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.net(x)


class _StopController:
    def __init__(self, rule: str, min_delta: float, patience: int, sma_window: int, ema_alpha: float, test_window: int, p_value: float):
        self.rule = rule
        self.min_delta = float(min_delta)
        self.patience = int(patience)
        self.sma_window = max(1, int(sma_window))
        self.ema_alpha = float(ema_alpha)
        self.test_window = max(2, int(test_window))
        self.p_value = float(p_value)
        self.best_value = float("inf")
        self.best_state = None
        self.patience_ctr = 0
        self.ema_value = None
        self.val_history: List[float] = []

    def _clone_state(self, model: nn.Module):
        return {k: v.detach().clone() for k, v in model.state_dict().items()}

    def _h_improved(self) -> bool:
        if len(self.val_history) < 2 * self.test_window:
            if len(self.val_history) == 1:
                return True
            return self.val_history[-1] < min(self.val_history[:-1])
        prev_window = self.val_history[-2 * self.test_window : -self.test_window]
        recent_window = self.val_history[-self.test_window :]
        _, p_value = ttest_ind(prev_window, recent_window, equal_var=False, alternative="greater")
        return bool(p_value < self.p_value)

    def step(self, model: nn.Module, current: float) -> bool:
        self.val_history.append(float(current))

        if self.rule == "none":
            self.best_state = self._clone_state(model)
            return False

        if self.rule == "h":
            improved = self._h_improved()
            if improved:
                self.best_state = self._clone_state(model)
                self.patience_ctr = 0
            else:
                self.patience_ctr += 1
            return self.patience_ctr >= self.patience

        if self.rule == "patience":
            monitor_value = float(current)
        elif self.rule == "sma":
            monitor_value = float(np.mean(self.val_history[-self.sma_window :]))
        elif self.rule == "ema":
            if self.ema_value is None:
                self.ema_value = current
            else:
                self.ema_value = self.ema_alpha * current + (1.0 - self.ema_alpha) * self.ema_value
            monitor_value = float(self.ema_value)
        else:
            raise ValueError(f"Unsupported stopping rule: {self.rule}")

        if (self.best_value - monitor_value) > self.min_delta:
            self.best_value = monitor_value
            self.best_state = self._clone_state(model)
            self.patience_ctr = 0
        else:
            self.patience_ctr += 1
        return self.patience_ctr >= self.patience


class TorchMLPRegressor:
    def __init__(
        self,
        input_dim: int,
        hidden_sizes: List[int],
        dropout: float = 0.0,
        activation: str = "relu",
        output_activation: str = "none",
        normalization: str = "none",
        init_method: str = "default",
        validation_strategy: str = "static",
        stopping_rule: str = "none",
    ):
        validation_strategy = str(validation_strategy).lower()
        stopping_rule = str(stopping_rule).lower()
        if validation_strategy not in VALIDATION_STRATEGIES:
            raise ValueError(f"validation_strategy must be one of {sorted(VALIDATION_STRATEGIES)}")
        if stopping_rule not in STOPPING_RULES:
            raise ValueError(f"stopping_rule must be one of {sorted(STOPPING_RULES)}")
        self.validation_strategy = validation_strategy
        self.stopping_rule = stopping_rule
        self.network = TorchMLPRegressorNet(
            input_dim,
            hidden_sizes,
            dropout=dropout,
            activation=activation,
            output_activation=output_activation,
            normalization=normalization,
            init_method=init_method,
        ).to(self._device())
        self.train_loss_hist: List[float] = []
        self.val_loss_hist: List[float] = []
        self.epochs_done: int = 0

    @staticmethod
    def _device():
        return torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    @staticmethod
    def _prep_xy(df: pd.DataFrame, target_col: str) -> Tuple[torch.Tensor, torch.Tensor]:
        X = df.drop(columns=[target_col]).to_numpy().astype(np.float32)
        y = df[target_col].to_numpy().astype(np.float32)
        return torch.from_numpy(X), torch.from_numpy(y).unsqueeze(-1)

    @staticmethod
    def _split_indices(n_samples: int, val_ratio: float) -> Tuple[np.ndarray, np.ndarray]:
        idx = np.arange(n_samples)
        np.random.shuffle(idx)
        n_val = max(1, int(n_samples * float(val_ratio)))
        return  idx[n_val:], idx[:n_val]

    def _epoch(self, loader: DataLoader, optimizer: Optional[torch.optim.Optimizer], criterion: nn.Module) -> float:
        losses: List[float] = []
        if optimizer is None:
            self.network.eval()
            with torch.no_grad():
                for xb, yb in loader:
                    xb = xb.float().to(self._device())
                    yb = yb.float().to(self._device())
                    losses.append(float(criterion(self.network(xb), yb).item()))
        else:
            self.network.train()
            for xb, yb in loader:
                xb = xb.float().to(self._device())
                yb = yb.float().to(self._device())
                optimizer.zero_grad()
                loss = criterion(self.network(xb), yb)
                loss.backward()
                optimizer.step()
                losses.append(float(loss.item()))
        return float(np.mean(losses)) if losses else 0.0

    def fit(self, df_train: pd.DataFrame, target_col: str, config: _TrainingConfig):

        X_all, y_all = self._prep_xy(df_train, target_col)
        criterion = nn.MSELoss()
        optimizer = torch.optim.Adam(self.network.parameters(), lr=float(config.lr))
        stopper = _StopController(self.stopping_rule, config.min_delta, config.patience, config.sma_window, config.ema_alpha, config.test_window, config.p_value)

        self.train_loss_hist = []
        self.val_loss_hist = []
        self.epochs_done = 0

        if self.validation_strategy == "static" and self.stopping_rule != "none":
            train_idx, val_idx = self._split_indices(X_all.shape[0], config.val_ratio)
            train_loader = DataLoader(TensorDataset(X_all[train_idx], y_all[train_idx]), batch_size=int(config.batch_size), shuffle=True, drop_last=False)
            val_loader = DataLoader(TensorDataset(X_all[val_idx], y_all[val_idx]), batch_size=int(config.batch_size), shuffle=False, drop_last=False)
        elif self.validation_strategy == "static":
            train_loader = DataLoader(TensorDataset(X_all, y_all), batch_size=int(config.batch_size), shuffle=True, drop_last=False)
            val_loader = None
        else:
            train_loader = None
            val_loader = None

        for epoch in range(int(config.epochs)):
            self.epochs_done += 1
            if self.validation_strategy == "dynamic" and (epoch % config.B) == 0:
                train_idx, val_idx = self._split_indices(X_all.shape[0], config.val_ratio)
                train_loader = DataLoader(TensorDataset(X_all[train_idx], y_all[train_idx]), batch_size=int(config.batch_size), shuffle=True, drop_last=False)
                val_loader = DataLoader(TensorDataset(X_all[val_idx], y_all[val_idx]), batch_size=int(config.batch_size), shuffle=False, drop_last=False)

            self.train_loss_hist.append(self._epoch(train_loader, optimizer, criterion))
            if val_loader is not None:
                val_loss = self._epoch(val_loader, None, criterion)
                self.val_loss_hist.append(val_loss)
                if stopper.step(self.network, val_loss):
                    break

        if stopper.best_state is not None:
            self.network.load_state_dict(stopper.best_state)
        return self

    def predict(self, df_test: pd.DataFrame, target_col: str, batch_size: int = 128):
        X = df_test.drop(columns=[target_col], errors="ignore").to_numpy().astype(np.float32)
        loader = DataLoader(TensorDataset(torch.from_numpy(X), torch.zeros(X.shape[0], 1)), batch_size=int(batch_size), shuffle=False, drop_last=False)
        preds: List[torch.Tensor] = []
        self.network.eval()
        with torch.no_grad():
            for xb, _ in loader:
                preds.append(self.network(xb.float().to(self._device())).detach().cpu())
        return torch.vstack(preds).squeeze(-1).numpy()


def torch_reg_mlp_create(
    input_dim: int,
    hidden_sizes: List[int],
    dropout: float = 0.0,
    activation: str = "relu",
    output_activation: str = "none",
    normalization: str = "none",
    init_method: str = "default",
    validation_strategy: str = "static",
    stopping_rule: str = "none",
):
    return TorchMLPRegressor(
        input_dim,
        hidden_sizes,
        dropout=dropout,
        activation=activation,
        output_activation=output_activation,
        normalization=normalization,
        init_method=init_method,
        validation_strategy=validation_strategy,
        stopping_rule=stopping_rule,
    )


def torch_reg_mlp_fit(
    model,
    df_train: pd.DataFrame,
    target_col: str = "t0",
    epochs: int = 100,
    lr: float = 1e-3,
    validation_strategy: str = "static",
    stopping_rule: str = "none",
    val_ratio: float = 0.2,
    batch_size: int = 64,
    patience: int = 100,
    min_delta: float = 1e-4,
    sma_window: int = 5,
    ema_alpha: float = 0.2,
    test_window: int = 30,
    p_value: float = 0.05,
    B: int = 1
):
    model.validation_strategy = str(validation_strategy).lower()
    model.stopping_rule = str(stopping_rule).lower()
    config = _TrainingConfig(
        epochs=int(epochs),
        lr=float(lr),
        val_ratio=float(val_ratio),
        batch_size=int(batch_size),
        patience=int(patience),
        min_delta=float(min_delta),
        sma_window=int(sma_window),
        ema_alpha=float(ema_alpha),
        test_window=int(test_window),
        p_value=float(p_value),
        B=int(B)
    )
    return model.fit(df_train, target_col=target_col, config=config)


def torch_reg_mlp_predict(model, df_test: pd.DataFrame, target_col: str = "t0", batch_size: int = 128):
    return model.predict(df_test, target_col=target_col, batch_size=batch_size)

# %% [markdown]
# ### Treinamento modelo estático

# %%
from sklearn.metrics import r2_score, root_mean_squared_error

es_rules = ['patience', 'h']

for sr in es_rules:
    for s in seeds:
        seed_everything(s)
        mlp_reg_es = torch_reg_mlp_create(
            input_dim=input_dim_student,
            hidden_sizes=hidden_sizes,
            dropout=0.1,
            validation_strategy="static",
            stopping_rule=sr
        )

        mlp_reg_es = torch_reg_mlp_fit(
            model=mlp_reg_es,
            df_train=df_train_mlp_reg,
            target_col=target_student,
            epochs=10000,
            validation_strategy="static",
            stopping_rule=sr,
            test_window=60,
            p_value=0.1
        )

        loss_hist_reg[f"{sr} static b{None} s{s}"] = {
            "train_loss": mlp_reg_es.train_loss_hist,
            "val_loss": mlp_reg_es.val_loss_hist,
            "model": f"{sr} static"
        }

        preds = torch_reg_mlp_predict(mlp_reg_es, df_test=df_test_mlp_reg, target_col='G3')

        r2 = r2_score(df_test_mlp_reg[target_student], preds)
        rmse = root_mean_squared_error(df_test_mlp_reg[target_student], preds)

        experiments_results_reg.append({
            "model": f"{sr} static",
            "R2": r2,
            "RMSE": rmse,
            "epochs": mlp_reg_es.epochs_done,
            "seed": s
        })

# %% [markdown]
# ### Treinamento validação em blocos

# %%
from sklearn.metrics import r2_score, root_mean_squared_error

es_rules = ['patience', 'h']
for sr in es_rules:
    for b in Blocos:
        for s in seeds:
            seed_everything(s)
            mlp_reg_es = torch_reg_mlp_create(
                input_dim=input_dim_student,
                hidden_sizes=hidden_sizes,
                dropout=0.1,
                validation_strategy="dynamic",
                stopping_rule=sr,
            )

            mlp_reg_es = torch_reg_mlp_fit(
                model=mlp_reg_es,
                df_train=df_train_mlp_reg,
                target_col=target_student,
                epochs=10000,
                validation_strategy="dynamic",
                stopping_rule=sr,
                B=b,
                test_window=60,
                p_value=0.1
            )

            loss_hist_reg[f"{sr} dynamic b{b:02d} s{s}"] = {
                "train_loss": mlp_reg_es.train_loss_hist,
                "val_loss": mlp_reg_es.val_loss_hist,
                "model": f"{sr} dynamic {b:02d}"
            }

            preds = torch_reg_mlp_predict(mlp_reg_es, df_test=df_test_mlp_reg, target_col=target_student)

            r2 = r2_score(df_test_mlp_reg[target_student], preds)
            rmse = root_mean_squared_error(df_test_mlp_reg[target_student], preds)

            experiments_results_reg.append({
                "model": f"{sr} dynamic {b:02d}",
                "R2": r2,
                "RMSE": rmse,
                "epochs": mlp_reg_es.epochs_done,
                "seed": s
            })

# %% [markdown]
# ### Salvando resultados

# %%
import json

df_res_reg = pd.DataFrame(experiments_results_reg)
df_res_reg.to_csv("results_reg.csv", index=False)

with open("loss_hist_reg.json", "w") as f:
    json.dump(loss_hist_reg, f, indent=4)

# %% [markdown]
# # Avaliação dos resultados

# %% [markdown]
# Import dos dados

# %%
import json
import pandas as pd

# Carrega a tabela
results_reg = pd.read_csv("results_reg.csv")
results_cla = pd.read_csv("results_cla.csv")

# Carrega o histórico de loss
with open("loss_hist_reg.json", "r") as f:
    loss_hist_reg = json.load(f)

with open("loss_hist_cla.json", "r") as f:
    loss_hist_cla = json.load(f)

print("Dados carregados...")
# Out:
# Dados carregados...

# %% [markdown]
# ### Avaliação no conjunto de teste

# %% [markdown]
# - Regressão

# %%
import pandas as pd

df_reg = pd.DataFrame(results_reg)

summary_reg = df_reg.groupby("model").agg(["mean", "std"])

print("===========================================================")
print(" MÉTRICAS DE TESTE - REGRESSÃO")
print("===========================================================")

metricas_reg = ["RMSE", "R2", "epochs"]

for model in summary_reg.index:
    print(f"\n{model}")
    for metric in metricas_reg:
        mean_val = summary_reg.loc[model, (metric, "mean")]
        std_val = summary_reg.loc[model, (metric, "std")]
        
        if metric == "epochs":
            print(f" - Epochs: {mean_val:.2f} ± {std_val:.5f}")
        else:
            print(f" - {metric}: {mean_val:.5f} ± {std_val:.5f}")
# Out:
# ===========================================================
#  MÉTRICAS DE TESTE - REGRESSÃO
# ===========================================================
#
# h dynamic 01
#  - RMSE: 2.56634 ± 0.10566
#  - R2: 0.67828 ± 0.02657
#  - Epochs: 1419.90 ± 276.68510
#
# h dynamic 05
#  - RMSE: 2.57378 ± 0.11937
#  - R2: 0.67627 ± 0.03015
#  - Epochs: 1394.63 ± 347.88231
#
# h dynamic 10
#  - RMSE: 2.54526 ± 0.10895
#  - R2: 0.68350 ± 0.02688
#  - Epochs: 1408.83 ± 364.72513
#
# h dynamic 20
#  - RMSE: 2.58421 ± 0.13704
#  - R2: 0.67343 ± 0.03486
#  - Epochs: 1513.90 ± 419.38390
#
# h dynamic 30
#  - RMSE: 2.58538 ± 0.10640
#  - R2: 0.67349 ± 0.02688
#  - Epochs: 1385.63 ± 490.61351
#
# h dynamic 50
#  - RMSE: 2.57249 ± 0.09941
#  - R2: 0.67680 ± 0.02544
#  - Epochs: 1282.00 ± 362.52924
#
# h static
#  - RMSE: 2.60847 ± 0.12273
#  - R2: 0.66746 ± 0.03161
#  - Epochs: 777.10 ± 456.53148
#
# patience dynamic 01
#  - RMSE: 2.64408 ± 0.09824
#  - R2: 0.65860 ± 0.02498
#  - Epochs: 715.70 ± 168.95116
#
# patience dynamic 05
#  - RMSE: 2.63787 ± 0.11050
#  - R2: 0.66008 ± 0.02839
#  - Epochs: 794.97 ± 216.11116
#
# patience dynamic 10
#  - RMSE: 2.63443 ± 0.09893
#  - R2: 0.66107 ± 0.02549
#  - Epochs: 676.23 ± 192.29515
#
# patience dynamic 20
#  - RMSE: 2.65716 ± 0.09326
#  - R2: 0.65526 ± 0.02417
#  - Epochs: 670.93 ± 189.99146
#
# patience dynamic 30
#  - RMSE: 2.65186 ± 0.11419
#  - R2: 0.65643 ± 0.02939
#  - Epochs: 606.33 ± 180.97520
#
# patience dynamic 50
#  - RMSE: 2.66452 ± 0.10376
#  - R2: 0.65325 ± 0.02685
#  - Epochs: 647.03 ± 203.93229
#
# patience static
#  - RMSE: 2.59967 ± 0.13106
#  - R2: 0.66960 ± 0.03361
#  - Epochs: 446.90 ± 177.17736

# %% [markdown]
# Os modelos com validação dinâmica apresetaram clara tendência de aumentar o número de épocas de treinamento, mas entre os modelos com mesma estratégia de parada e validação, alternando apenas o valor B, do número de blocos, não vemos uma clara tendência linear de aumento ou diminuição nas épocas.
#
# O modelo que obteve as melhores métricas foi o h dynamic 10, apresentando maior R2 e menor RMSE em relação a todos os outros modelos, ainda que a variação tenha sido pequena.
#
# Nos modelos com early stopping usando paciência o modelo patience static foi quem teve as melhores métricas com diferença desprezível dos modelos patience dynamic 10 e 5.

# %% [markdown]
# - Classificação

# %%
import pandas as pd

df_cla = pd.DataFrame(results_cla)

summary_cla = df_cla.groupby("model").agg(["mean", "std"])

print("===========================================================")
print(" MÉTRICAS DE TESTE - CLASSIFICAÇÃO")
print("===========================================================")

metrics_cla = ["acc", "precision", "recall", "F1", "epochs"]

for model in summary_cla.index:
    print(f"\n{model}")
    for metric in metrics_cla:
        mean_val = summary_cla.loc[model, (metric, "mean")]
        std_val = summary_cla.loc[model, (metric, "std")]
        
        if metric == "epochs":
            print(f" - epochs: {mean_val:.2f} ± {std_val:.5f}")
        else:
            print(f" - {metric}: {mean_val:.5f} ± {std_val:.5f}")
# Out:
# ===========================================================
#  MÉTRICAS DE TESTE - CLASSIFICAÇÃO
# ===========================================================
#
# h dynamic 01
#  - acc: 0.68089 ± 0.00945
#  - precision: 0.67002 ± 0.01321
#  - recall: 0.63180 ± 0.00975
#  - F1: 0.63227 ± 0.01071
#  - epochs: 594.70 ± 262.01752
#
# h dynamic 05
#  - acc: 0.68065 ± 0.00942
#  - precision: 0.67018 ± 0.01340
#  - recall: 0.63086 ± 0.00951
#  - F1: 0.63109 ± 0.01040
#  - epochs: 915.07 ± 509.60072
#
# h dynamic 10
#  - acc: 0.68462 ± 0.01012
#  - precision: 0.67463 ± 0.01329
#  - recall: 0.63603 ± 0.01131
#  - F1: 0.63696 ± 0.01261
#  - epochs: 972.53 ± 614.16811
#
# h dynamic 20
#  - acc: 0.68718 ± 0.00917
#  - precision: 0.67780 ± 0.01116
#  - recall: 0.63909 ± 0.01173
#  - F1: 0.64028 ± 0.01321
#  - epochs: 577.47 ± 414.43503
#
# h dynamic 30
#  - acc: 0.68601 ± 0.01076
#  - precision: 0.67701 ± 0.01286
#  - recall: 0.63675 ± 0.01358
#  - F1: 0.63745 ± 0.01535
#  - epochs: 582.77 ± 302.17210
#
# h dynamic 50
#  - acc: 0.68625 ± 0.00984
#  - precision: 0.67626 ± 0.01209
#  - recall: 0.63843 ± 0.01224
#  - F1: 0.63964 ± 0.01374
#  - epochs: 690.03 ± 542.13209
#
# h static
#  - acc: 0.68811 ± 0.01487
#  - precision: 0.67742 ± 0.01809
#  - recall: 0.64208 ± 0.01828
#  - F1: 0.64376 ± 0.02025
#  - epochs: 253.03 ± 108.67652
#
# patience dynamic 01
#  - acc: 0.68205 ± 0.01172
#  - precision: 0.66982 ± 0.01425
#  - recall: 0.63551 ± 0.01544
#  - F1: 0.63653 ± 0.01704
#  - epochs: 295.60 ± 116.73507
#
# patience dynamic 05
#  - acc: 0.68718 ± 0.01021
#  - precision: 0.67722 ± 0.01153
#  - recall: 0.63994 ± 0.01445
#  - F1: 0.64116 ± 0.01621
#  - epochs: 261.53 ± 92.80076
#
# patience dynamic 10
#  - acc: 0.68718 ± 0.01131
#  - precision: 0.67735 ± 0.01363
#  - recall: 0.63973 ± 0.01470
#  - F1: 0.64097 ± 0.01633
#  - epochs: 229.53 ± 65.48216
#
# patience dynamic 20
#  - acc: 0.68671 ± 0.01237
#  - precision: 0.67619 ± 0.01455
#  - recall: 0.63956 ± 0.01554
#  - F1: 0.64094 ± 0.01736
#  - epochs: 229.87 ± 80.65539
#
# patience dynamic 30
#  - acc: 0.69021 ± 0.01339
#  - precision: 0.68092 ± 0.01611
#  - recall: 0.64338 ± 0.01658
#  - F1: 0.64507 ± 0.01834
#  - epochs: 235.70 ± 102.02980
#
# patience dynamic 50
#  - acc: 0.68601 ± 0.01122
#  - precision: 0.67590 ± 0.01470
#  - recall: 0.63856 ± 0.01348
#  - F1: 0.63978 ± 0.01503
#  - epochs: 254.07 ± 76.41535
#
# patience static
#  - acc: 0.69371 ± 0.01626
#  - precision: 0.68246 ± 0.01916
#  - recall: 0.65082 ± 0.02052
#  - F1: 0.65350 ± 0.02258
#  - epochs: 205.17 ± 103.60904

# %% [markdown]
# A tendência de mais épocas para modelos com validação dinâmica se manteve na classificação.
#
# O modelo com melhores métricas macro foi o de paciência estático, com o melhor dinâmico sendo o de paciência com reamostragem a cada 30 épocas.
#
# Nos modelo com early stopping usando teste de hipótese(h) o que teve melhores métricas foi o estático, o melhor dinâmico teve reamostragem a cada 20 épocas.

# %% [markdown]
# ### Curvas de validação

# %% [markdown]
# - Regressão

# %%
import matplotlib.pyplot as plt

# seleciona 1 seed para vizualização
seed = seeds[0]

models_reg = sorted(list(set([lh["model"] for lh in loss_hist_reg.values()])))

fig, axes = plt.subplots(3, 5, figsize=(18, 12))
axes = axes.flatten()  # Transforma a matriz em uma lista linear para facilitar o loop

for i, model in enumerate(models_reg):
    ax = axes[i]
    
    for key, hist in loss_hist_reg.items():
        if key.endswith(f" s{seed}") and hist["model"] == model:
            # Pega a partir da época 15 pra melhor vizualização pela escala
            loss = hist["val_loss"][15:]
            epochs = range(len(hist["val_loss"]) - 15)
            
            ax.plot(epochs, loss)
            
    ax.set_title(model, fontweight='bold')
    ax.set_xlabel("Epochs", fontsize=9)
    ax.set_ylabel("Loss", fontsize=9)
    ax.grid(True, linestyle="--")


for j in range(len(models_reg), len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Classificação

# %%
import matplotlib.pyplot as plt

# seleciona 1 seed para vizualização
seed = seeds[0]

models_cla = sorted(list(set([lh["model"] for lh in loss_hist_cla.values()])))

fig, axes = plt.subplots(3, 5, figsize=(18, 12))
axes = axes.flatten()  # Transforma a matriz em uma lista linear para facilitar o loop

for i, nome_modelo in enumerate(models_cla):
    ax = axes[i]
    
    for key, hist in loss_hist_cla.items():
        if key.endswith(f" s{seed}") and hist["model"] == nome_modelo:
            ax.plot(hist["val_loss"])
            
    ax.set_title(nome_modelo, fontweight='bold')
    ax.set_xlabel("Epochs")
    ax.set_ylabel("Loss")
    ax.grid(True, linestyle="--")


for j in range(len(models_cla), len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em uma análise prelimilar dos gráficos da curva de loss na validação, percebemos que quanto menor o número de blocos, maior a tendência do modelo de criar oscilações nas curvas, causando sua subida e queda. Porém o aumento no hiperparâmetro B não significa necessariamente uma curva suave, ele aparenta causar um delay nas mudanças bruscas que ocorrem. Visto que a diferença nos picos e vales parece a mesma.

# %% [markdown]
# ### Boxplot Diferença Épocas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

limiar_oscilacao = 0.005  # Sensibilidade para detectar solavancos no MSE

metricas_reg = []
diffs_boxplot_reg = []

for key, hist in loss_hist_reg.items():
    model = hist["model"]
    val_loss = hist["val_loss"][15:]
        
    diffs = np.diff(val_loss)
    diffs_abs = np.abs(diffs)

    for d in diffs_abs:
        diffs_boxplot_reg.append({"Model": model, "diff": d})
        
    # Estatísticas diferenças
    val_loss_std = np.std(val_loss)
    var_mean = np.mean(diffs_abs)
    max_diff = np.max(diffs_abs)
    max_spike = np.max(diffs)
    
    # Contagem de oscilações
    inflexions = np.diff(np.sign(diffs))
    oscilacoes = np.sum((inflexions != 0) & (diffs_abs[:-1] > limiar_oscilacao))

    # Porcentagem de vezes que val loss subiu
    up_loss = np.mean(diffs > limiar_oscilacao) * 100

    # Variação pouco antes da parada
    lag = 20
    idx_min = np.argmin(val_loss)
    wind = val_loss[idx_min - lag : idx_min + 1]
    lag_mean = np.mean(wind)
    lag_std = np.std(wind)

    metricas_reg.append({
        "Model": model,
        "Val Loss std": val_loss_std,
        "Variação Média": var_mean,
        "Oscilações Relev.": oscilacoes,
        "Maior Variação": max_diff,
        "Maior Subida": max_spike,
        "Porcentagem Subida": up_loss,
        f"Variação últimas {lag} épocas": lag_mean,
        f"Desvio ùltimas {lag} épocas": lag_std
    })


df_box_reg = pd.DataFrame(diffs_boxplot_reg)
plt.figure(figsize=(12, 5))
sns.boxplot(data=df_box_reg, x="Model", y="diff", palette="viridis")
plt.title("Boxplot Diferenças Val Loss - REGRESSÃO")
plt.xlabel("Model")
plt.ylabel("Variação Absoluta")
plt.yscale('log')  # Escala logarítmica para não esmagar os boxes com os maiores spikes
plt.xticks(rotation=25)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\KonigAdler\AppData\Local\Temp\ipykernel_18824\679744885.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_box_reg, x="Model", y="diff", palette="viridis")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

limiar_oscilacao = 0.005  # Sensibilidade para detectar solavancos

metricas_cla = []
diffs_boxplot_cla = []

for key, hist in loss_hist_cla.items():
    model = hist["model"]
    val_loss = hist["val_loss"]  # Curva completa para classificação
        
    diffs = np.diff(val_loss)
    diffs_abs = np.abs(diffs)

    for d in diffs_abs:
        diffs_boxplot_cla.append({"Model": model, "diff": d})
        
    # Estatísticas diferenças
    val_loss_std = np.std(val_loss)
    var_mean = np.mean(diffs_abs)
    max_diff = np.max(diffs_abs)
    max_spike = np.max(diffs)
    
    # Contagem de oscilações
    inflexions = np.diff(np.sign(diffs))
    oscilacoes = np.sum((inflexions != 0) & (diffs_abs[:-1] > limiar_oscilacao))

    # Porcentagem de vezes que val loss subiu
    up_loss = np.mean(diffs > limiar_oscilacao) * 100

    # Variação pouco antes da parada
    lag = 20
    idx_min = np.argmin(val_loss)
    wind = val_loss[idx_min - lag : idx_min + 1]
    lag_std = np.std(wind)

    metricas_cla.append({
        "Model": model,
        "Val Loss std": val_loss_std,
        "Variação Média": var_mean,
        "Oscilações Relev.": oscilacoes,
        "Maior Variação": max_diff,
        "Maior Subida": max_spike,
        "Porcentagem Subida": up_loss,
        f"Desvio ùltimas {lag} épocas": lag_std
    })


df_box_cla = pd.DataFrame(diffs_boxplot_cla)
plt.figure(figsize=(12, 5))
sns.boxplot(data=df_box_cla, x="Model", y="diff", palette="viridis")
plt.title("Boxplot Diferenças Val Loss - CLASSIFICAÇÃO")
plt.xlabel("Model")
plt.ylabel("Variação Absoluta")
plt.yscale('log')  # Escala logarítmica para não esmagar os boxes com os maiores spikes
plt.xticks(rotation=25)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\KonigAdler\Documents\GitHub\Machine_Learning\.venv\Lib\site-packages\numpy\_core\_methods.py:219: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\KonigAdler\Documents\GitHub\Machine_Learning\.venv\Lib\site-packages\numpy\_core\_methods.py:178: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# c:\Users\KonigAdler\Documents\GitHub\Machine_Learning\.venv\Lib\site-packages\numpy\_core\_methods.py:211: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\KonigAdler\AppData\Local\Temp\ipykernel_18824\2166319635.py:54: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_box_cla, x="Model", y="diff", palette="viridis")

# %% [markdown]
# O gráfico foi plotado escala logarítima visto que pelo número de outliers altos os intervalos interquartis estavam esmagados. Não podemos perceber nenhuma relação na distribuição dos diferenças de loss entre tamanhos de blocos de validação diferentes, mas podemos ver em ambos os gráficos que os modelos estáticos apresentam uma distribuição mais concentrada, com menos outliers, mas também um menor ajuste fino, visto que quanto menor a diferença, mais estável a curva se manteve mais para baixo o bigode no gráfico.

# %% [markdown]
# ### Métricas de estabilidade

# %%
df_resumo_reg = pd.DataFrame(metricas_reg)
summary_reg = df_resumo_reg.groupby("Model").agg(["mean", "std"])

print("======================================================================")
print("Métricas Estabilidade Val Loss - REGRESSÃO")
print("======================================================================")

for model in summary_reg.index:
    print(f"\n{model}")

    for col in df_resumo_reg.columns:
        if col != "Model":
            m_val = summary_reg.loc[model, (col, "mean")]
            s_val = summary_reg.loc[model, (col, "std")]
            
            print(f" - {col}: {m_val:.5f} ± {s_val:.5f}")
# Out:
# ======================================================================
# Métricas Estabilidade Val Loss - REGRESSÃO
# ======================================================================
#
# h dynamic 01
#  - Val Loss std: 3.23821 ± 0.34037
#  - Variação Média: 0.32509 ± 0.06498
#  - Oscilações Relev.: 897.26667 ± 168.93437
#  - Maior Variação: 10.63803 ± 2.28642
#  - Maior Subida: 9.65282 ± 2.40863
#  - Porcentagem Subida: 47.60694 ± 0.90355
#  - Variação últimas 20 épocas: 0.16053 ± 0.04433
#  - Desvio ùltimas 20 épocas: 0.05663 ± 0.01740
#
# h dynamic 05
#  - Val Loss std: 3.27218 ± 0.41216
#  - Variação Média: 0.11612 ± 0.02016
#  - Oscilações Relev.: 728.40000 ± 197.56249
#  - Maior Variação: 7.04067 ± 2.46401
#  - Maior Subida: 5.66760 ± 2.30346
#  - Porcentagem Subida: 48.41529 ± 1.40282
#  - Variação últimas 20 épocas: 0.16902 ± 0.04788
#  - Desvio ùltimas 20 épocas: 0.05465 ± 0.02173
#
# h dynamic 10
#  - Val Loss std: 3.32921 ± 0.41948
#  - Variação Média: 0.09282 ± 0.01647
#  - Oscilações Relev.: 728.36667 ± 204.12192
#  - Maior Variação: 6.59548 ± 1.95912
#  - Maior Subida: 4.27548 ± 2.16721
#  - Porcentagem Subida: 48.02930 ± 1.34854
#  - Variação últimas 20 épocas: 0.18470 ± 0.06326
#  - Desvio ùltimas 20 épocas: 0.05455 ± 0.02202
#
# h dynamic 20
#  - Val Loss std: 3.34513 ± 0.44432
#  - Variação Média: 0.07898 ± 0.01182
#  - Oscilações Relev.: 782.43333 ± 233.31829
#  - Maior Variação: 6.10691 ± 2.07710
#  - Maior Subida: 3.22030 ± 1.94272
#  - Porcentagem Subida: 46.35848 ± 1.08114
#  - Variação últimas 20 épocas: 0.18496 ± 0.06610
#  - Desvio ùltimas 20 épocas: 0.05263 ± 0.01435
#
# h dynamic 30
#  - Val Loss std: 3.60175 ± 0.64270
#  - Variação Média: 0.08013 ± 0.01409
#  - Oscilações Relev.: 707.83333 ± 271.15527
#  - Maior Variação: 5.72207 ± 2.22652
#  - Maior Subida: 2.28790 ± 1.64772
#  - Porcentagem Subida: 45.39671 ± 1.21240
#  - Variação últimas 20 épocas: 0.22623 ± 0.07745
#  - Desvio ùltimas 20 épocas: 0.05827 ± 0.01892
#
# h dynamic 50
#  - Val Loss std: 3.75231 ± 0.67864
#  - Variação Média: 0.07773 ± 0.01225
#  - Oscilações Relev.: 646.06667 ± 204.50730
#  - Maior Variação: 4.54177 ± 2.04793
#  - Maior Subida: 1.15776 ± 0.95359
#  - Porcentagem Subida: 44.55236 ± 1.36946
#  - Variação últimas 20 épocas: 0.28912 ± 0.11193
#  - Desvio ùltimas 20 épocas: 0.08258 ± 0.03892
#
# h static
#  - Val Loss std: 3.54732 ± 0.89990
#  - Variação Média: 0.09710 ± 0.04050
#  - Oscilações Relev.: 348.76667 ± 241.58681
#  - Maior Variação: 1.44829 ± 1.11218
#  - Maior Subida: 0.62137 ± 0.33264
#  - Porcentagem Subida: 38.86963 ± 3.65678
#  - Variação últimas 20 épocas: 4.45130 ± 1.32002
#  - Desvio ùltimas 20 épocas: 0.11863 ± 0.05241
#
# patience dynamic 01
#  - Val Loss std: 4.29629 ± 0.45831
#  - Variação Média: 0.59295 ± 0.12701
#  - Oscilações Relev.: 454.06667 ± 105.77397
#  - Maior Variação: 10.63803 ± 2.28642
#  - Maior Subida: 9.65282 ± 2.40863
#  - Porcentagem Subida: 48.24937 ± 1.15727
#  - Variação últimas 20 épocas: 0.35237 ± 0.16055
#  - Desvio ùltimas 20 épocas: 0.09917 ± 0.05684
#
# patience dynamic 05
#  - Val Loss std: 4.11130 ± 0.44831
#  - Variação Média: 0.16584 ± 0.02790
#  - Oscilações Relev.: 392.10000 ± 125.23395
#  - Maior Variação: 7.04067 ± 2.46401
#  - Maior Subida: 5.66760 ± 2.30346
#  - Porcentagem Subida: 50.07869 ± 1.51569
#  - Variação últimas 20 épocas: 0.30831 ± 0.10939
#  - Desvio ùltimas 20 épocas: 0.08137 ± 0.03674
#
# patience dynamic 10
#  - Val Loss std: 4.44929 ± 0.57247
#  - Variação Média: 0.14284 ± 0.03996
#  - Oscilações Relev.: 317.60000 ± 104.92414
#  - Maior Variação: 6.59548 ± 1.95912
#  - Maior Subida: 4.27548 ± 2.16721
#  - Porcentagem Subida: 49.27083 ± 2.04843
#  - Variação últimas 20 épocas: 0.59184 ± 0.75232
#  - Desvio ùltimas 20 épocas: 0.15614 ± 0.22331
#
# patience dynamic 20
#  - Val Loss std: 4.59109 ± 0.59122
#  - Variação Média: 0.11686 ± 0.01957
#  - Oscilações Relev.: 310.63333 ± 106.23542
#  - Maior Variação: 6.10691 ± 2.07710
#  - Maior Subida: 3.21756 ± 1.94685
#  - Porcentagem Subida: 46.50938 ± 1.96668
#  - Variação últimas 20 épocas: 0.56049 ± 0.53101
#  - Desvio ùltimas 20 épocas: 0.10617 ± 0.09081
#
# patience dynamic 30
#  - Val Loss std: 4.84513 ± 0.75778
#  - Variação Média: 0.11656 ± 0.02389
#  - Oscilações Relev.: 275.56667 ± 101.53976
#  - Maior Variação: 5.72207 ± 2.22652
#  - Maior Subida: 2.28790 ± 1.64772
#  - Porcentagem Subida: 44.37143 ± 2.73861
#  - Variação últimas 20 épocas: 0.79058 ± 0.57349
#  - Desvio ùltimas 20 épocas: 0.15310 ± 0.11973
#
# patience dynamic 50
#  - Val Loss std: 4.79859 ± 0.86574
#  - Variação Média: 0.10716 ± 0.02181
#  - Oscilações Relev.: 296.53333 ± 112.15252
#  - Maior Variação: 4.54177 ± 2.04793
#  - Maior Subida: 1.15629 ± 0.95459
#  - Porcentagem Subida: 42.45401 ± 3.09005
#  - Variação últimas 20 épocas: 0.86644 ± 0.59485
#  - Desvio ùltimas 20 épocas: 0.15855 ± 0.10637
#
# patience static
#  - Val Loss std: 4.20257 ± 0.98331
#  - Variação Média: 0.10888 ± 0.03855
#  - Oscilações Relev.: 179.36667 ± 90.90559
#  - Maior Variação: 1.44105 ± 1.11636
#  - Maior Subida: 0.58893 ± 0.33726
#  - Porcentagem Subida: 34.60669 ± 3.91059
#  - Variação últimas 20 épocas: 4.59189 ± 1.27941
#  - Desvio ùltimas 20 épocas: 0.11519 ± 0.04130

# %% [markdown]
# **Comportamento do Desvio Padrão e Diferenças**
#
# O desvio padrão da curva *(Val Loss std)* apresentou tendência de subida com o aumento do número do blocos, o modelo estático apresentou variação próximo, mas menor do maior bloco testado.
#
# As diferenças foram calculadas conforme a fórmula:
#
#
# $$Loss_t - Loss_{t-1}$$
#
# **Média das Diferenças e Oscilações**
#
# * Média das Diferenças *(Variação Média)*: O modelo estático tem uma variação média baixa, mas ela é comparável aos blocos intermediários e grandes, e não a menor de todas.
# * Número de Oscilações (*Oscilações Relev*): A número de oscilações(mudanças de direção) tem uma tendência geral de queda quanto maior o valor de B, salvo o B com valor 20 que teve um aumento. Como o número de épocas dos modelos estáticos é naturalmente menor, ele naturalmente tem a menor oscilação nesses casos.
#
# **Variação de Épocas Consecutivas e Tendências de Subida**
#
# A maior diferença na variação *(Maior Variação)* de épocas consecutivas também se apresenta inversamente proporcional ao valor de B. Mas isso não necessarimente é ruim, dado que a curva pode estar diminuindo o erro.
#
# Olhando o maior spike (*maior subida*) vemos que é consistente com a métrica acima, mas sempre um pouco menor.
#
# Olhanto o quanto a curva subiu *(Porcentagem Subida)* temos o aumento de blocos de tamanho 1 para 5 e tendência de diminuição apartir desses, sendo desconsiderados diferenças dentro de um limiar definido em 0.005.
#
# **Desvio Padrão no Final do Treinamento**
#
# Sobre o desvio padrão da curva no final do treinamento(últimas 20 épocas antes do ponto de menor val loss), curiosamente os modelos com menor B apresentaram desvio menor, com exceção do modelo estático usando paciência que ficou com valor comparável aos valores de B intermediários.

# %%
df_resumo_cla = pd.DataFrame(metricas_cla)
summary_cla = df_resumo_cla.groupby("Model").agg(["mean", "std"])

print("======================================================================")
print("Métricas Estabilidade Val Loss - CLASSIFICAÇÃO")
print("======================================================================")

for model in summary_cla.index:
    print(f"\n{model}")

    for col in df_resumo_cla.columns:
        if col != "Model":
            m_val = summary_cla.loc[model, (col, "mean")]
            s_val = summary_cla.loc[model, (col, "std")]
            
            print(f" - {col}: {m_val:.5f} ± {s_val:.5f}")
# Out:
# ======================================================================
# Métricas Estabilidade Val Loss - CLASSIFICAÇÃO
# ======================================================================
#
# h dynamic 01
#  - Val Loss std: 0.04779 ± 0.00203
#  - Variação Média: 0.04503 ± 0.00200
#  - Oscilações Relev.: 369.06667 ± 166.59013
#  - Maior Variação: 0.19577 ± 0.02980
#  - Maior Subida: 0.18720 ± 0.03263
#  - Porcentagem Subida: 46.08470 ± 1.29999
#  - Variação últimas 20 épocas: 0.50126 ± 0.02113
#  - Desvio ùltimas 20 épocas: 0.04630 ± 0.00492
#
# h dynamic 05
#  - Val Loss std: 0.04958 ± 0.00406
#  - Variação Média: 0.01233 ± 0.00085
#  - Oscilações Relev.: 166.03333 ± 95.33696
#  - Maior Variação: 0.17510 ± 0.02788
#  - Maior Subida: 0.15139 ± 0.03062
#  - Porcentagem Subida: 23.50749 ± 3.05410
#  - Variação últimas 20 épocas: 0.48711 ± 0.03396
#  - Desvio ùltimas 20 épocas: 0.04098 ± 0.01196
#
# h dynamic 10
#  - Val Loss std: 0.04952 ± 0.00435
#  - Variação Média: 0.00818 ± 0.00074
#  - Oscilações Relev.: 134.60000 ± 80.86285
#  - Maior Variação: 0.16672 ± 0.03841
#  - Maior Subida: 0.12704 ± 0.03534
#  - Porcentagem Subida: 18.69306 ± 2.37716
#  - Variação últimas 20 épocas: 0.49936 ± 0.03962
#  - Desvio ùltimas 20 épocas: 0.03323 ± 0.00881
#
# h dynamic 20
#  - Val Loss std: 0.04680 ± 0.00567
#  - Variação Média: 0.00600 ± 0.00087
#  - Oscilações Relev.: 72.96667 ± 54.18581
#  - Maior Variação: 0.13464 ± 0.03848
#  - Maior Subida: 0.09269 ± 0.02379
#  - Porcentagem Subida: 14.63052 ± 2.26583
#  - Variação últimas 20 épocas: 0.51573 ± 0.04566
#  - Desvio ùltimas 20 épocas: 0.02509 ± 0.01203
#
# h dynamic 30
#  - Val Loss std: 0.04666 ± 0.00848
#  - Variação Média: 0.00508 ± 0.00056
#  - Oscilações Relev.: 65.60000 ± 31.03346
#  - Maior Variação: 0.13614 ± 0.04595
#  - Maior Subida: 0.08324 ± 0.03532
#  - Porcentagem Subida: 13.32108 ± 2.40697
#  - Variação últimas 20 épocas: 0.53129 ± 0.04496
#  - Desvio ùltimas 20 épocas: 0.02474 ± 0.01696
#
# h dynamic 50
#  - Val Loss std: 0.04748 ± 0.01121
#  - Variação Média: 0.00439 ± 0.00059
#  - Oscilações Relev.: 72.06667 ± 56.90945
#  - Maior Variação: 0.13277 ± 0.05361
#  - Maior Subida: 0.07056 ± 0.03661
#  - Porcentagem Subida: 12.03831 ± 2.81328
#  - Variação últimas 20 épocas: 0.54386 ± 0.05051
#  - Desvio ùltimas 20 épocas: 0.02404 ± 0.01077
#
# h static
#  - Val Loss std: 0.01832 ± 0.00457
#  - Variação Média: 0.00340 ± 0.00161
#  - Oscilações Relev.: 24.66667 ± 21.30458
#  - Maior Variação: 0.01683 ± 0.00708
#  - Maior Subida: 0.01266 ± 0.00562
#  - Porcentagem Subida: 9.57539 ± 7.90930
#  - Variação últimas 20 épocas: 0.56412 ± 0.03282
#  - Desvio ùltimas 20 épocas: 0.00523 ± 0.00528
#
# patience dynamic 01
#  - Val Loss std: 0.04741 ± 0.00225
#  - Variação Média: 0.04436 ± 0.00260
#  - Oscilações Relev.: 184.10000 ± 75.35953
#  - Maior Variação: 0.17844 ± 0.02981
#  - Maior Subida: 0.16683 ± 0.03320
#  - Porcentagem Subida: 46.05282 ± 1.82505
#  - Variação últimas 20 épocas: 0.52291 ± 0.01583
#  - Desvio ùltimas 20 épocas: 0.04333 ± 0.00551
#
# patience dynamic 05
#  - Val Loss std: 0.04629 ± 0.00389
#  - Variação Média: 0.01184 ± 0.00145
#  - Oscilações Relev.: 47.96667 ± 15.13726
#  - Maior Variação: 0.14216 ± 0.02757
#  - Maior Subida: 0.11450 ± 0.02686
#  - Porcentagem Subida: 20.61006 ± 2.24139
#  - Variação últimas 20 épocas: 0.53489 ± 0.02610
#  - Desvio ùltimas 20 épocas: 0.03956 ± 0.01237
#
# patience dynamic 10
#  - Val Loss std: 0.04588 ± 0.00533
#  - Variação Média: 0.00799 ± 0.00102
#  - Oscilações Relev.: 32.76667 ± 9.74037
#  - Maior Variação: 0.12504 ± 0.03254
#  - Maior Subida: 0.10061 ± 0.02387
#  - Porcentagem Subida: 15.89829 ± 2.38940
#  - Variação últimas 20 épocas: 0.53793 ± 0.02984
#  - Desvio ùltimas 20 épocas: 0.03784 ± 0.01564
#
# patience dynamic 20
#  - Val Loss std: 0.04539 ± 0.00803
#  - Variação Média: 0.00591 ± 0.00088
#  - Oscilações Relev.: 29.63333 ± 11.29383
#  - Maior Variação: 0.10954 ± 0.03753
#  - Maior Subida: 0.07341 ± 0.02775
#  - Porcentagem Subida: 13.21781 ± 2.61055
#  - Variação últimas 20 épocas: 0.53553 ± 0.03835
#  - Desvio ùltimas 20 épocas: 0.02603 ± 0.01681
#
# patience dynamic 30
#  - Val Loss std: 0.04646 ± 0.00954
#  - Variação Média: 0.00536 ± 0.00085
#  - Oscilações Relev.: 28.23333 ± 11.82832
#  - Maior Variação: 0.10021 ± 0.03554
#  - Maior Subida: 0.07147 ± 0.02750
#  - Porcentagem Subida: 12.72477 ± 3.52891
#  - Variação últimas 20 épocas: 0.53492 ± 0.03778
#  - Desvio ùltimas 20 épocas: 0.02082 ± 0.01609
#
# patience dynamic 50
#  - Val Loss std: 0.04778 ± 0.01263
#  - Variação Média: 0.00471 ± 0.00090
#  - Oscilações Relev.: 31.00000 ± 14.12994
#  - Maior Variação: 0.10184 ± 0.04727
#  - Maior Subida: 0.06431 ± 0.03774
#  - Porcentagem Subida: 11.99024 ± 4.24441
#  - Variação últimas 20 épocas: 0.54319 ± 0.03599
#  - Desvio ùltimas 20 épocas: 0.01916 ± 0.01322
#
# patience static
#  - Val Loss std: 0.02010 ± 0.00584
#  - Variação Média: 0.00348 ± 0.00161
#  - Oscilações Relev.: 19.16667 ± 14.59354
#  - Maior Variação: 0.01676 ± 0.00706
#  - Maior Subida: 0.01257 ± 0.00553
#  - Porcentagem Subida: 9.52256 ± 7.77158
#  - Variação últimas 20 épocas: 0.56402 ± 0.03276
#  - Desvio ùltimas 20 épocas: 0.00523 ± 0.00533

# %% [markdown]
# **Comportamento do Desvio Padrão e Diferenças**
#
# O desvio padrão da curva (*Val Loss std*) apresentou estabilidade independente do número de blocos usado na validação.
#
# **Média das Diferenças e Oscilações**
#
# * Média das Diferenças *(Variação Média)*: Apresenta uma queda rigorosa e inversamente proporcional ao valor de B.
# * Número de Oscilações (*Oscilações Relev.*): A número de oscilações relevantes cai proporcionalmente conforme B aumenta, tendo apenas uma leve subida quando B é 50.
#
# **Variação de Épocas Consecutivas e Tendências de Subida**
#
# A diferença consecutiva (*Maior Variação*) e o maior pico (*Maior Subida*) reduzem progressivamente com o aumento de B.
#
# Diferente da regressão, a porcentagem de vezes que houve aumento no validation loss (*Porcentagem Subida*) decresceu agressivamente com o aumento dos blocos, despencando de aproximadamente 46% (B=1) para a faixa de 12% (B=50).
#
# **Desvio Padrão no Final do Treinamento**
#
# Sobre o desvio padrão da curva no final do treinamento o comportamento inverteu-se em relação à regressão: os blocos maiores (B=30 e B=50) conseguiram entregar maior estabilidade no final do treinamento do que os blocos menores. Com os modelos estáticos apresentando a maior estabilidade.

# %% [markdown]
# # Conclusão

# %% [markdown]
# Em suma, a validação dinâmica em blocos surge como uma alternativa promissora quando se opta por usar a validação dinâmica. Os modelos dinâmicos usando alguns blocos obtiveram melhores métricas que a alternativa estática por uma pequena margem. Todavia as métricas em classificação tiverem ficado favoráveis aos modelos com validação estática, os melhores modelos dinâmicos ficaram atrás por valores muito pequenos. Isso pode indicar que em cenários que compensa usar a validação dinâmica, vale a pena fazer a reamostragem por blocos buscando ajuste fino para se obter um modelo melhor.
# Vale a pena mencionar que a reamostragem por blocos não se demonstrou muito eficiente para suavizar o ruído da curva de validação, visto que a variação dos picos após reamostragem se manteve parecida nos gráficos, algumas métricas de estabilidade podem estar escondendo o real valor pelo uso da média.
